# %%
import pandas as pd

# %%
pet_names = pd.read_table('pet names.txt')

# %%
pet_names.shape
# Out:
# (784, 4)

# %%
pet_names.head()
# Out:
#                                             nickname Last char First char  len
# 0  my babbeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee         e          m   49
# 1     babbeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee         e          b   46
# 2                   my sprinkle on my ice cream cone         e          m   32
# 3                     my sweet, sweet cheetah kitten         n          m   30
# 4                      cottage cheese chicken breast         t          c   29

# %%
chats = pd.read_table('Babe chats data_utf.txt')

# %%
import io
import shutil

with io.open('Babe chats data.txt', encoding='utf-8', errors='ignore') as source:
    with io.open('Babe chats data_utf.txt', mode='w', encoding='utf-8') as target:
        shutil.copyfileobj(source, target)

# %%
chats.head()
# Out:
#                     Date  Month    Year  Day  Year & Month  Year Month Day  \
# 0   7/10/2015 3:05:20 PM    7.0  2015.0   10       20157.0       2015710.0
# 1   7/10/2015 3:05:20 PM    7.0  2015.0   10       20157.0       2015710.0
# 2   7/10/2015 3:34:54 PM    7.0  2015.0   10       20157.0       2015710.0
# 3   7/10/2015 5:11:54 PM    7.0  2015.0   10       20157.0       2015710.0
# 4  7/11/2015 10:01:51 AM    7.0  2015.0   11       20157.0       2015711.0
#
#   Type Which babe Message len
# 0  SMS       Jess     NaN   0
# 1  SMS       Jess     NaN   0
# 2  SMS       Jess     NaN   0
# 3  SMS       Jess     NaN   0
# 4  SMS       Jess     NaN   0

# %%
chats.shape
# Out:
# (76923, 10)

# %%
lower_chat = []

for chat in chats.Message:
    if isinstance(chat, float) is False:
        lower_chat.append(chat)
    elif isinstance(chat, long) is False:
        lower_chat.append(chat)
    else:
        lower_chat.append(chat.lower())

# %%
len(lower_chat)
# Out:
# 76923

# %%
pet_names_lower = []

for name in pet_names.nickname:
    pet_names_lower.append(name.lower())

# %%
pet_names_lower
# Out:
# ['my babbeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee',
#  'babbeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee',
#  'my sprinkle on my ice cream cone',
#  'my sweet, sweet cheetah kitten',
#  'cottage cheese chicken breast',
#  'my little sweet baby kangaroo',
#  'sprinkle on my ice cream cone',
#  'my sweeeeeet ray of sunshine',
#  'my biggest cinnamon pretzel',
#  'sweet, sweet cheetah kitten',
#  'little sweet baby kangaroo',
#  'my sweet sweet cute angel',
#  'sweeeeeet ray of sunshine',
#  'my baggy of gummy fruits',
#  'my piece of citrus fruit',
#  'my sweet sweet honey bun',
#  'my dollop of sour cream',
#  'my poor sweet nice girl',
#  'my sweet nice cute girl',
#  'my sweet apple crumble',
#  'sweet sweet cute angel',
#  'baggy of gummy fruits',
#  'my good favorite girl',
#  'my sweet nice boobela',
#  'my sweet, lovely girl',
#  'piece of citrus fruit',
#  'sweet sweet honey bun',
#  'dollop of sour cream',
#  'my lil princess frog',
#  'my little kitten cat',
# ...

# %%
name_mentions = []

for chat in lower_chat:
    for name in pet_names_lower:
        if isinstance(chat, int) is False:
            if isinstance(chat, float) is False:
                if name in chat:
                    name_mentions.append(name)
                else:
                    name_mentions.append(0)

# %%
#this is finding ALL matches, but we only want it to return the first one
len(name_mentions)
# Out:
# 60234720

# %%
import re

def findWholeWord(w):
    return re.compile(r'\b({0})\b'.format(w), flags=re.IGNORECASE).search

findWholeWord('seek')('those who seek shall find')    # -> <match object>
findWholeWord('word')('swordsmith')                   # -> None

# %%
findWholeWord('word')('swordsmith')

# %%
if 'seek sha' in 'those who seek shall find':
    print('Success!')
